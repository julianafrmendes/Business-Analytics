# %% [markdown]
# <a href="https://colab.research.google.com/github/julianafrmendes/Business-Analytics/blob/master/Analise_preco_gasolina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='blue'>Núcleo Data Science LGPDNOW</font>
#
#
# # <font color='blue'>Projeto de análise de dados </font>
# # <font color='blue'>Projeto 1</font>
# ## <font color='blue'>Comparativo de preços de gasolina no Brasil</font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.11.11

# %%
# Instala o pacote watermark.
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.9 MB/s eta 0:00:00

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Juliana Franco Mendes" --iversions
# Out:
# Author: Juliana Franco Mendes
#
# plotly  : 5.24.1
# platform: 1.0.8
# pandas  : 2.2.2

# %% [markdown]
# Link para Dataset: https://www.kaggle.com/datasets/matheusfreitag/gas-prices-in-brazil

# %% [markdown]
# ## Neste projeto, trabalharemos com dois arquivos csvs separados, contendo informações sobre o preço da gasolina no Brasil.
#
# ### 1. Carregue os conjuntos de dados "gasolina_2000+.csv" e "gasolina_2010+.csv" em dois DataFrames diferentes e combine-os em um único DataFrame.

# %%
import pandas as pd

df1 = pd.read_csv('gasolina_2000+.csv')
df2 = pd.read_csv('gasolina_2010+.csv')
df = pd.concat([df1, df2])
# Out:
# <ipython-input-1-8bd33e24669b>:4: DtypeWarning: Columns (12,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('gasolina_2010+.csv')

# %% [markdown]
# ### 2.Investigue as colunas e entenda o conjunto de dados usando o head() e info()

# %%
df.head(5)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120823 entries, 0 to 78184
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     120823 non-null  int64
#  1   DATA INICIAL                   120823 non-null  object
#  2   DATA FINAL                     120823 non-null  object
#  3   REGIÃO                         120823 non-null  object
#  4   ESTADO                         120823 non-null  object
#  5   PRODUTO                        120823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  7   UNIDADE DE MEDIDA              120823 non-null  object
#  8   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           120823 non-null  float64
# ...

# %% [markdown]
# ### 3. Selecione a terceira entrada da coluna DATA INICIAL e verifique seu tipo.

# %%
df['DATA INICIAL'].iloc[2]
# Out:
# '2004-05-09'

# %%
type(df['DATA INICIAL'].iloc[2])
# Out:
# str

# %% [markdown]
# ### 4. Você deve ter percebido que as colunas DATA INICIAL e DATA FINAL estão formatadas como string. Utilizando o método pd.to_datetime(), converta ambas colunas para Timestamp / Datetime.

# %%
df['DATA INICIAL'] = pd.to_datetime(df['DATA INICIAL'])
df['DATA FINAL'] = pd.to_datetime(df['DATA FINAL'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120823 entries, 0 to 78184
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     120823 non-null  int64
#  1   DATA INICIAL                   120823 non-null  datetime64[ns]
#  2   DATA FINAL                     120823 non-null  datetime64[ns]
#  3   REGIÃO                         120823 non-null  object
#  4   ESTADO                         120823 non-null  object
#  5   PRODUTO                        120823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  7   UNIDADE DE MEDIDA              120823 non-null  object
#  8   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           120823 non-null  float64
# ...

# %% [markdown]
# ### 5. Crie uma nova coluna para representar o ano e o mês(aaaa-mm), utilizando a coluna DATA FINAL como referência.

# %%
df['mes_ano'] = df['DATA FINAL'].dt.to_period('M')
df.head()
# Out:
#    Unnamed: 0 DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# ...

# %% [markdown]
# ### 6. Utilizando o value_counts(), liste todos os tipos de produtos contidos na base de dados.

# %%
Produtos = df['PRODUTO'].value_counts()
Produtos
# Out:
# PRODUTO
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Filtre o DataFrame para obter apenas dados da 'GASOLINA COMUM'. Grave em uma nova variável.

# %%
gasolina_comum = df[df['PRODUTO'] == 'GASOLINA COMUM']

# %%
gasolina_comum.head()
# Out:
#       Unnamed: 0 DATA INICIAL DATA FINAL        REGIÃO              ESTADO  \
# 9256       12064   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 9257       12065   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS
# 9258       12066   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO
# 9259       12067   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 9260       12068   2004-05-09 2004-05-15      NORDESTE             ALAGOAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 9256  GASOLINA COMUM                           128              R$/l
# 9257  GASOLINA COMUM                           395              R$/l
# 9258  GASOLINA COMUM                           194              R$/l
# 9259  GASOLINA COMUM                           166              R$/l
# 9260  GASOLINA COMUM                           106              R$/l
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# ...

# %% [markdown]
# ### 8. Qual o preço médio de revenda da gasolina em agosto de 2008?

# %%
gasolina_comum['ano'] = gasolina_comum['DATA INICIAL'].dt.year
df_ago = gasolina_comum[(gasolina_comum['mes_ano'] == '2008-08') & (gasolina_comum['ano'] == 2008)]
pm_ago = df_ago.groupby('mes_ano')['PREÇO MÉDIO REVENDA'].mean()
pm_ago
# Out:
# <ipython-input-16-b9886991399e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gasolina_comum['ano'] = gasolina_comum['DATA INICIAL'].dt.year
# mes_ano
# 2008-08    2.601244
# Freq: M, Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# ### 9. Qual o preço médio de revenda da gasolina em maio de 2014 em São Paulo?

# %%
gasolina_comum.head(3)
# Out:
#       Unnamed: 0 DATA INICIAL DATA FINAL        REGIÃO            ESTADO  \
# 9256       12064   2004-05-09 2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 9257       12065   2004-05-09 2004-05-15  CENTRO OESTE             GOIAS
# 9258       12066   2004-05-09 2004-05-15  CENTRO OESTE       MATO GROSSO
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 9256  GASOLINA COMUM                           128              R$/l
# 9257  GASOLINA COMUM                           395              R$/l
# 9258  GASOLINA COMUM                           194              R$/l
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 9256                2.029                  0.007  ...                  2.07
# 9257                2.025                  0.062  ...                  2.22
# 9258                2.358                  0.066  ...                  2.54
#
#       MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# ...

# %%
df_sp_2014 = gasolina_comum[(gasolina_comum['ESTADO'] == 'SAO PAULO') & (gasolina_comum['ano'] == 2014)]
sp_05_24 = df_sp_2014.groupby('mes_ano')['PREÇO MÉDIO REVENDA'].mean()#.iloc[4]
print("O preço de médio de revenda em SP para o mês de Maio de 2014 é: R$",sp_05_24)
# Out:
# O preço de médio de revenda em SP para o mês de Maio de 2014 é: R$ mes_ano
# 2014-01    2.83700
# 2014-02    2.83425
# 2014-03    2.87600
# 2014-04    2.89000
# 2014-05    2.88220
# 2014-06    2.86925
# 2014-07    2.85950
# 2014-08    2.85380
# 2014-09    2.84800
# 2014-10    2.84450
# 2014-11    2.87700
# 2014-12    2.90450
# 2015-01    2.90300
# Freq: M, Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# ### 10. Você conseguiria descobrir em qual(quais) estado(s) a gasolina ultrapassou a barreira dos R$ 5,00? E quando isso ocorreu?

# %%
up_5 = gasolina_comum[gasolina_comum['PREÇO MÉDIO REVENDA'] > 5].sort_index()
estados_up_5 = up_5.groupby('ESTADO')['DATA INICIAL'].min().reset_index()

# %%
select_gasolina = gasolina_comum[['ESTADO', 'DATA INICIAL', 'PREÇO MÉDIO REVENDA']]

df_uf_valor = estados_up_5.merge(
    select_gasolina,
    on=['ESTADO', 'DATA INICIAL'],
    how='inner'
)

# %%
print(" Primeiro registro da gasolina acima de R$5,00 em cada estado:\n",df_uf_valor )
# Out:
#  Primeiro registro da gasolina acima de R$5,00 em cada estado:
#                   ESTADO DATA INICIAL  PREÇO MÉDIO REVENDA
# 0                  ACRE   2018-05-20                5.053
# 1               ALAGOAS   2021-02-14                5.084
# 2              AMAZONAS   2021-02-21                5.014
# 3                 BAHIA   2021-02-14                5.070
# 4                 CEARA   2021-02-14                5.135
# 5      DISTRITO FEDERAL   2021-02-07                5.087
# 6        ESPIRITO SANTO   2021-02-21                5.172
# 7                 GOIAS   2021-02-21                5.371
# 8              MARANHAO   2021-02-21                5.252
# 9           MATO GROSSO   2021-02-28                5.189
# 10   MATO GROSSO DO SUL   2021-02-14                5.024
# 11         MINAS GERAIS   2021-02-14                5.043
# 12                 PARA   2021-02-14                5.058
# 13              PARAIBA   2021-02-21                5.027
# ...

# %% [markdown]
# ### 11. Qual a média de preço dos estados da região sul em 2012?

# %%
df_sul_12 = gasolina_comum[(gasolina_comum['REGIÃO']=='SUL') & (gasolina_comum['ano'] == 2012) ]
df_sul_12_price = df_sul_12.groupby('ano')['PREÇO MÉDIO REVENDA'].mean()
df_sul_12_price
# Out:
# ano
# 2012    2.722453
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# ### 12. Você conseguiria obter uma tabela contendo a variação percentual ano a ano para o estado do Rio de Janeiro?

# %%
df_rio = gasolina_comum[gasolina_comum['ESTADO'] == 'RIO DE JANEIRO']
df_rio_anual = df_rio.groupby('ano')['PREÇO MÉDIO REVENDA'].mean().reset_index()

# %%
df_rio_anual_pivot = df_rio_anual.pivot_table(index='ano', values= 'PREÇO MÉDIO REVENDA')
df_rio_anual_pivot['percentual_crescimento'] = (df_rio_anual_pivot['PREÇO MÉDIO REVENDA'].pct_change()*100)
df_rio_anual_pivot
# Out:
#       PREÇO MÉDIO REVENDA  percentual_crescimento
# ano
# 2004             2.175500                     NaN
# 2005             2.339500                7.538497
# 2006             2.560679                9.454125
# 2007             2.532288               -1.108721
# 2008             2.547308                0.593109
# 2009             2.566120                0.738517
# 2010             2.648673                3.217039
# 2011             2.835846                7.066673
# 2012             2.853698                0.629511
# 2013             2.998885                5.087662
# 2014             3.134635                4.526683
# 2015             3.549882               13.247086
# 2016             3.919192               10.403442
# 2017             4.112774                4.939316
# 2018             4.858058               18.121204
# 2019             4.858173                0.002375
# 2020             4.761205               -1.995988
# 2021             5.625294               18.148550

# %% [markdown]
# DESAFIO: Crie uma tabela contendo uma serie temporal com a diferença absoluta e percentual entre os valores mais baratos e caros. Apresente também ao lado os estados na qual os maiores e menores preços foram registrados.

# %%
#descriçao de valores
df['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    120823.000000
# mean         11.473440
# std          19.161823
# min           0.766000
# 25%           2.157000
# 50%           2.899000
# 75%           4.026000
# max         107.500000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
#merge de dataframes min e max
min = gasolina_comum.groupby(['DATA INICIAL'])['PREÇO MÉDIO REVENDA'].min().reset_index()
max = gasolina_comum.groupby(['DATA INICIAL'])['PREÇO MÉDIO REVENDA'].max().reset_index()

diff = max.merge(min, on='DATA INICIAL')

# %%
diff
# Out:
#     DATA INICIAL  PREÇO MÉDIO REVENDA_x  PREÇO MÉDIO REVENDA_y
# 0     2004-05-09                  2.388                  1.891
# 1     2004-05-16                  2.438                  1.888
# 2     2004-05-23                  2.438                  1.894
# 3     2004-05-30                  2.435                  1.912
# 4     2004-06-06                  2.437                  1.919
# ..           ...                    ...                    ...
# 868   2021-03-28                  6.220                  4.812
# 869   2021-04-04                  6.227                  4.811
# 870   2021-04-11                  6.216                  4.777
# 871   2021-04-18                  6.212                  4.795
# 872   2021-04-25                  6.258                  4.867
#
# [873 rows x 3 columns]

# %%
#renomear colunas
diff.rename(columns={'PREÇO MÉDIO REVENDA_x': 'max', 'PREÇO MÉDIO REVENDA_y': 'min'}, inplace=True)

# %%
#calcula diferença percentual
diff['diff%'] = ((diff['max'] - diff['min']) / diff['min']) * 100

# %%
#calcula diferença absoluta
diff['diff_abs'] = abs(diff['max'] - diff['min'])

# %%
diff['min'].describe()
# Out:
# count    873.000000
# mean       2.897719
# std        0.641101
# min        1.888000
# 25%        2.401000
# 50%        2.624000
# 75%        3.442000
# max        4.935000
# Name: min, dtype: float64

# %%
#separa os valores de difereança absoluta maxima
max_diff = diff.sort_values(by='diff_abs', ascending = False).head(15)
max_diff
# Out:
#     DATA INICIAL    max    min      diff%  diff_abs
# 866   2021-03-14  6.688  4.895  36.629213     1.793
# 843   2020-08-09  4.948  3.454  43.254198     1.494
# 827   2020-04-19  4.521  3.033  49.060336     1.488
# 842   2020-08-02  4.912  3.443  42.666279     1.469
# 824   2020-03-29  4.841  3.378  43.309651     1.463
# 841   2020-07-26  4.911  3.453  42.224153     1.458
# 835   2020-06-14  4.608  3.156  46.007605     1.452
# 844   2020-08-16  4.969  3.524  41.004540     1.445
# 838   2020-07-05  4.749  3.304  43.734867     1.445
# 837   2020-06-28  4.718  3.278  43.929225     1.440
# 870   2021-04-11  6.216  4.777  30.123508     1.439
# 839   2020-07-12  4.812  3.375  42.577778     1.437
# 836   2020-06-21  4.670  3.246  43.869378     1.424
# 830   2020-05-10  4.363  2.945  48.149406     1.418
# 871   2021-04-18  6.212  4.795  29.551616     1.417

# %%
#Separa os valores de diferença absoluta minímos
min_diff = diff.sort_values(by='diff_abs', ascending = False).tail(15)
min_diff
# Out:
#     DATA INICIAL    max    min      diff%  diff_abs
# 26    2004-11-07  2.583  2.096  23.234733     0.487
# 47    2005-04-03  2.671  2.185  22.242563     0.486
# 49    2005-04-17  2.670  2.184  22.252747     0.486
# 51    2005-05-01  2.670  2.186  22.140897     0.484
# 45    2005-03-20  2.671  2.188  22.074954     0.483
# 28    2004-11-21  2.589  2.108  22.817837     0.481
# 52    2005-05-08  2.666  2.186  21.957914     0.480
# 5     2004-06-13  2.437  1.958  24.463739     0.479
# 27    2004-11-14  2.582  2.103  22.776985     0.479
# 50    2005-04-24  2.666  2.188  21.846435     0.478
# 44    2005-03-13  2.642  2.165  22.032333     0.477
# 7     2004-06-27  2.510  2.033  23.462863     0.477
# 46    2005-03-27  2.665  2.189  21.745089     0.476
# 356   2011-04-03  3.064  2.588  18.392581     0.476
# 6     2004-06-20  2.496  2.036  22.593320     0.460

# %%
#agrupamento  para buscar os estados com valores mínimos
gr5 =  gasolina_comum.groupby(['DATA INICIAL', 'ESTADO'])['PREÇO MÉDIO REVENDA'].min().reset_index()

#RENOMEIA COLUNA
gr5.rename(columns={'PREÇO MÉDIO REVENDA': 'min'}, inplace=True)

#junta no elemento comum on=['DATA INICIAL', 'min']
preco_min = gr5.merge(min_diff, on=['DATA INICIAL', 'min'], how='inner')
preco_min.sort_values(by='diff_abs', ascending=False)

#seleciona os valores de interesse na tabela
preco_min = preco_min[['DATA INICIAL', 'ESTADO', 'min']].sort_values(by='DATA INICIAL', ascending=False)

# %%
import plotly.express as px

fig = px.line(x=preco_min['DATA INICIAL'],
         y=preco_min['min'],
         labels={'x': 'Data', 'y': 'Preco'},
         width=1500,
         height=400,
         hover_name= preco_min['ESTADO'],
         markers=True,
         template= 'plotly_dark',
         title='Menores valores registrados de gasolina comum')

 # Exibir o gráfico
fig.show()
print(preco_min)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#agrupamento  para encontrar estados de valores maximos
gr7 =  gasolina_comum.groupby(['DATA INICIAL', 'ESTADO'])['PREÇO MÉDIO REVENDA'].max().reset_index()

#RENOMEIA COLUNA
gr7.rename(columns={'PREÇO MÉDIO REVENDA': 'max'}, inplace=True)

#junta no elemento comum on=['DATA INICIAL', 'min']
preco_max= gr7.merge(max_diff, on=['DATA INICIAL', 'max'], how='inner')
preco_max.sort_values(by='diff_abs', ascending=False)

#seleciona os valores de interesse na tabela
preco_max = preco_max[['DATA INICIAL', 'ESTADO', 'max']].sort_values(by='DATA INICIAL', ascending=False)

# %%
import plotly.express as px

fig = px.line(x=preco_max['DATA INICIAL'],
         y=preco_max['max'],
         labels={'x': 'Data', 'y': 'Preco'},
         width=1500,
         height=400,
         hover_name= preco_max['ESTADO'],
         markers=True,
         template= 'plotly_dark',
         title='Maiores valores registrados de gasolina comum')
 # Exibir o gráfico
fig.show()
print(preco_max)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###FIM
